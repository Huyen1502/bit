# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %%
# btc_monthly = yf.download("BTC-USD", start="2010-01-01", interval="1mo")
# btc_monthly.to_csv("btc_monthly.csv")

#btc_daily = yf.download("BTC-USD", start="2010-01-01", interval="1d")
#btc_daily.to_csv("btc_daily.csv")

# %%
df_daily_price_up_down_percentage = pd.read_csv("C:\\Users\\nguye\\Documents\\Bit\\output\\spreadsheet\\btc_daily_metrics.csv", encoding="utf-8")
df_daily_price_up_down_percentage.head(5)
# Out:
#          Date       Close        High         Low        Open    Volume  \
# 0  2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 1  2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2  2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 3  2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 4  2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100
#
#    daily_return_pct   ath_close  drawdown_pct  is_bear regime
# 0               NaN  457.334015      0.000000    False   bull
# 1         -7.192558  457.334015     -7.192558    False   bull
# 2         -6.984265  457.334015    -13.674475    False   bull
# 3          3.573492  457.334015    -10.589639    False   bull
# 4         -2.465854  457.334015    -12.794369    False   bull

# %%
df_monthly_price_up_down_percentage = pd.read_csv("C:\\Users\\nguye\\Documents\\Bit\\output\\spreadsheet\\btc_monthly_returns.csv", encoding="utf-8")
df_monthly_price_up_down_percentage
# Out:
#       month_end  month_end_close      ath_close  drawdown_pct  \
# 0    2014-09-30       386.944000     386.944000      0.000000
# 1    2014-10-31       338.321014     386.944000    -12.565897
# 2    2014-11-30       378.046997     386.944000     -2.299300
# 3    2014-12-31       320.192993     386.944000    -17.250818
# 4    2015-01-31       217.464005     386.944000    -43.799618
# ..          ...              ...            ...           ...
# 133  2025-10-31    109556.164062  115758.203125     -5.357753
# 134  2025-11-30     90394.312500  115758.203125    -21.911096
# 135  2025-12-31     87508.828125  115758.203125    -24.403778
# 136  2026-01-31     78621.117188  115758.203125    -32.081602
# 137  2026-02-28     63018.984375  115758.203125    -45.559811
#
#      monthly_return_pct regime  year  month
# 0                   NaN   bull  2014      9
# 1            -12.565897   bull  2014     10
# 2             11.742097   bull  2014     11
# ...

# %%
df_monthly_return = pd.read_csv("C:\\Users\\nguye\\Documents\\Bit\\output\\spreadsheet\\btc_monthly_returns.csv", encoding="utf-8")
df_monthly_return.head(5)
# Out:
#     month_end  month_end_close  ath_close  drawdown_pct  monthly_return_pct  \
# 0  2014-09-30       386.944000    386.944      0.000000                 NaN
# 1  2014-10-31       338.321014    386.944    -12.565897          -12.565897
# 2  2014-11-30       378.046997    386.944     -2.299300           11.742097
# 3  2014-12-31       320.192993    386.944    -17.250818          -15.303389
# 4  2015-01-31       217.464005    386.944    -43.799618          -32.083459
#
#   regime  year  month
# 0   bull  2014      9
# 1   bull  2014     10
# 2   bull  2014     11
# 3   bull  2014     12
# 4   bear  2015      1

# %%
bull_bear_cycle_monthly= pd.read_csv("C:\\Users\\nguye\\Documents\\Bit\\output\\spreadsheet\\btc_monthly_bull_bear_cycles.csv", encoding="utf-8")
bull_bear_cycle_monthly
# Out:
#    cycle_no  bull_start    bull_end  bear_start    bear_end  \
# 0         1  2014-09-30  2014-12-31  2015-01-31  2015-09-30
# 1         2  2015-10-31  2017-12-31  2018-01-31  2020-07-31
# 2         3  2020-08-31  2020-08-31  2020-09-30  2020-09-30
# 3         4  2020-10-31  2021-04-30  2021-05-31  2021-07-31
# 4         5  2021-08-31  2021-08-31  2021-09-30  2021-09-30
# 5         6  2021-10-31  2021-11-30  2021-12-31  2024-01-31
# 6         7  2024-02-29  2025-10-31  2025-11-30  2026-02-28
#
#    bull_duration_days  bear_duration_days  cycle_duration_days  \
# 0                  93                 243                  366
# 1                 793                 913                 1736
# 2                   1                   1                   31
# 3                 182                  62                  274
# 4                   1                   1                   31
# 5                  31                 762                  823
# ...

# %%
bull_bear_cycle= pd.read_csv("C:\\Users\\nguye\\Documents\\Bit\\output\\spreadsheet\\btc_bull_bear_cycles.csv", encoding="utf-8")
bull_bear_cycle
# Out:
#     cycle_no  bull_start    bull_end  bear_start    bear_end  \
# 0          1  2014-09-17  2014-10-02  2014-10-03  2014-10-11
# 1          2  2014-10-12  2014-10-22  2014-10-23  2014-11-09
# 2          3  2014-11-10  2014-11-19  2014-11-20  2014-11-22
# 3          4  2014-11-23  2014-12-07  2014-12-08  2015-11-02
# 4          5  2015-11-03  2015-11-09  2015-11-10  2015-11-28
# 5          6  2015-11-29  2015-11-30  2015-12-01  2015-12-04
# 6          7  2015-12-05  2016-01-14  2016-01-15  2016-01-15
# 7          8  2016-01-16  2016-01-30  2016-01-31  2016-01-31
# 8          9  2016-02-01  2016-02-02  2016-02-03  2016-02-03
# 9         10  2016-02-04  2016-06-21  2016-06-22  2016-06-22
# 10        11  2016-06-23  2016-07-31  2016-08-01  2016-09-06
# 11        12  2016-09-07  2016-09-10  2016-09-11  2016-09-30
# 12        13  2016-10-01  2016-10-01  2016-10-02  2016-10-06
# 13        14  2016-10-07  2017-01-05  2017-01-06  2017-01-21
# ...
